# %%
# %pylab
# %matplotlib inline
import seaborn as sns
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
frangidicestd = [0.05,
0.05,
0.05,
0.04,
0.04]

oursdicestd = [0.04,
0.04,
0.03,
0.03,
0.03]

# %%
frangidice = [0.79282, 0.79148, 0.78971, 0.756, 0.64297]
ourdice = [0.85285, 0.87409, 0.89239, 0.87203,  0.7428]
x = np.array(range(len(frangidice)))/10

# %%
plt.figure(figsize=(12, 12))
sns.set_theme('notebook')
sns.set(font_scale=2.4)
plt.errorbar(x, frangidice, yerr=frangidicestd, linewidth=3)
plt.errorbar(x, ourdice, yerr=oursdicestd, linewidth=3)
plt.xlabel('Value of $\sigma$')
plt.ylabel('Dice score')
plt.legend(['Frangi', 'Ours'])
plt.title('Noise sensitivity on VascuSynth dataset')
# Out:
# Text(0.5, 1.0, 'Noise sensitivity on VascuSynth dataset')

# %%
frangiauc = [0.99427, 0.99165, 0.98632, 0.97854, 0.95994]
oursauc = [0.99926, 0.99951, 0.99891, 0.99558, 0.98395]

# Std
frangiaucstd = np.array([0,
0.04,
0.05,
0.06,
0.06])

oursaucstd = np.array([
    0,
    0,
    0.01,
    0.01,
    0.01
])

print(oursaucstd, frangiaucstd)
# Out:
# [0.   0.   0.01 0.01 0.01] [0.   0.04 0.05 0.06 0.06]

# %%
plt.figure(figsize=(12, 12))
sns.set_theme('notebook')
sns.set(font_scale=2.4)
plt.errorbar(x, frangiauc, yerr=list(frangiaucstd/5), linewidth=3)
plt.errorbar(x, oursauc, yerr=list(oursaucstd/5), linewidth=3)
plt.xlabel('Value of $\sigma$')
plt.ylabel('AUC')
plt.legend(['Frangi', 'Ours'])
plt.title('Noise sensitivity on VascuSynth dataset')
# Out:
# Text(0.5, 1.0, 'Noise sensitivity on VascuSynth dataset')
