# %%
# %pylab
# %matplotlib inline
from data_loader.drivegenesisdataset import *
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
ds = DriveGenesisDataset("/pghbio/dbmi/batmanlab/rohit33/DRIVE/")

# %%
ds[0]
# Out:
# {'gt': tensor([[[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 7.5659e-12,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [3.0541e-02, 2.7188e-02, 2.4118e-02,  ..., 2.7734e-02,
#            2.7673e-02, 2.6944e-02],
#           [3.0804e-02, 2.7430e-02, 2.7167e-02,  ..., 2.5767e-02,
#            2.5767e-02, 2.2920e-02],
#           [2.7451e-02, 2.4098e-02, 2.4098e-02,  ..., 5.8905e-03,
#            8.9803e-03, 9.0007e-03]]]),
#  'image': tensor([[[-5.9520e-08, -5.9520e-08, -5.9520e-08,  ..., -5.9520e-08,
#            -5.9520e-08, -5.9520e-08],
#           [-5.9520e-08, -5.9520e-08, -5.9520e-08,  ..., -5.9520e-08,
#            -5.9520e-08, -5.9520e-08],
#           [-5.9520e-08, -5.9520e-08, -5.9336e-08,  ..., -5.9520e-08,
#            -5.9520e-08, -5.9520e-08],
# ...

# %%
plt.figure(figsize=(16, 16))
plt.subplot(121)
plt.imshow(ds[0]['image'][0], 'gray')
plt.subplot(122)
plt.imshow(ds[0]['gt'][0], 'gray')
