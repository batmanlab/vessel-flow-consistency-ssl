# %%
from hrfdataset import HRFDataset
from ritedataset import RITEDataset

# %%
ds = HRFDataset("/ocean/projects/asc170022p/rohit33/HRF_dataset")

# %%
d = ds[0]

# %%
import numpy as np
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(figsize=(12,12))
plt.imshow(d['mask'][0])

# %%
from PIL import Image

# %%
path = ds.images[10]
img = Image.open(path)
img = np.array(img)/255.0
print(img.shape)
plt.figure(figsize=(12,12))
plt.imshow(img)
# Out:
# (2336, 3504, 3)

# %% [markdown]
# # RITE Dataset

# %%
ls  $PROJECT/RITE_dataset/training/images
# Out:
# 21_training.tif  26_training.tif  31_training.tif  36_training.tif
# 22_training.tif  27_training.tif  32_training.tif  37_training.tif
# 23_training.tif  28_training.tif  33_training.tif  38_training.tif
# 24_training.tif  29_training.tif  34_training.tif  39_training.tif
# 25_training.tif  30_training.tif  35_training.tif  40_training.tif

# %%
dsr = RITEDataset("/ocean/projects/asc170022p/rohit33/RITE_dataset", augment=False, train=False)
print(len(dsr))
# Out:
# 20

# %%
plt.figure(figsize=(12,12))
plt.imshow(dsr[0]['seg'][0])

# %%
# Masks
plt.figure(figsize=(20,20))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(dsr[i]['image'][0] > 20/255.)
